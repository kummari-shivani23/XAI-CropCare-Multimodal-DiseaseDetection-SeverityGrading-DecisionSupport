# %%
import os

PROJECT_ROOT = os.path.abspath("...")
os.chdir(PROJECT_ROOT)

print("Current working directory:", os.getcwd())

BASE = "data/processed/grapes"

for split in ["train", "val", "test"]:
    print(f"\n{split.upper()}")
    for cls in os.listdir(os.path.join(BASE, split)):
        count = len(os.listdir(os.path.join(BASE, split, cls)))
        print(f"{cls}: {count}")
# Out:
# Current working directory: C:\Users\Prasanna\XAI-CropCare-Multimodal-DiseaseDetection-SeverityGrading-DecisionSupport\src
#
# TRAIN
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 12
#      10 for split in ["train", "val", "test"]:
#      11     print(f"\n{split.upper()}")
# ---> 12     for cls in os.listdir(os.path.join(BASE, split)):
#      13         count = len(os.listdir(os.path.join(BASE, split, cls)))
#      14         print(f"{cls}: {count}")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/processed/grapes\\train'
